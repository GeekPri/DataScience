# %%
import pandas as pd
import numpy as ny
dataset = pd.read_csv("Placement.csv")
from Univariate import Univariate
quan, qual = Univariate.getQuanQual(dataset)

# %%
dataset.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
descriptive = Univariate.getDescriptiveWithUnivariatesValues(dataset, quan)

# %%
outlineFields = Univariate.findOutlinerFields(descriptive, quan)

# %%
dataset = Univariate.replaceOutline(outlineFields, dataset, descriptive)

# %%
freqTableList = []
for quanColumnName in quan:
    freqTableList.append(Univariate.freqTable(dataset, quanColumnName))

# %%
freqTableList
# Out:
# [     uniqueValue  frequency  relative_frequency    cumsum
#  0            215          1            0.004651  0.004651
#  1             80          1            0.004651  0.009302
#  2             78          1            0.004651  0.013953
#  3             77          1            0.004651  0.018605
#  4             76          1            0.004651  0.023256
#  ..           ...        ...                 ...       ...
#  210          140          1            0.004651  0.981395
#  211          139          1            0.004651  0.986047
#  212          138          1            0.004651  0.990698
#  213          137          1            0.004651  0.995349
#  214            1          1            0.004651  1.000000
#
#  [215 rows x 4 columns],
#       uniqueValue  frequency  relative_frequency    cumsum
#  0          62.00         11            0.106796  0.106796
#  1          63.00         10            0.097087  0.203883
# ...

# %%
dataset.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.334744   66.358558   72.100558   62.278186
# std     62.209324   10.827205   10.586016    7.321524   13.275956    5.833385
# min      1.000000   40.890000   42.750000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   91.150000   88.500000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   277648.648649
# std     54264.139179
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    390000.000000

# %%
outlineFields
# Out:
# (['hsc_p', 'degree_p', 'salary'], ['hsc_p'])

# %%
outlineFields
# Out:
# ([], [])
